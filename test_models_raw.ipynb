# %%
import os
import torch
import tqdm
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    BitsAndBytesConfig,
    AutoTokenizer,
    pipeline,
)
import gc
from tqdm import tqdm
import json
import re

# %%
model_name = "meta-llama/Llama-2-7b-hf"

#dataset_name = "kokujin/prompts_1"

dataset_name = "yale-nlp/QTSumm"

# %%
test = load_dataset(dataset_name, split="test")

# %%
opt = model_name + "_raw"
dic = {opt: []}

# %%
# LoRA attention dimension
lora_r = 64

# Alpha parameter for LoRA scaling
lora_alpha = 16

# Dropout probability for LoRA layers
lora_dropout = 0.1

# %%
# Activate 8-bit precision base model loading
use_8bit = True

# Compute dtype for 4-bit base models
bnb_8bit_compute_dtype = "float16"

# Quantization type (fp4 or nf4)
bnb_4bit_quant_type = "nf4"

# Activate nested quantization for 4-bit base models (double quantization)
use_nested_quant = False

# %%
# Output directory where the model predictions and checkpoints will be stored
output_dir = f"./results/{model_name}/"

# Number of training epochs
num_train_epochs = 2

# Enable fp16/bf16 training (set bf16 to True with an A100)
fp16 = False
bf16 = False

# Batch size per GPU for training
per_device_train_batch_size = 1

# Batch size per GPU for evaluation
per_device_eval_batch_size = 1

# Number of update steps to accumulate the gradients for
gradient_accumulation_steps = 3

# Enable gradient checkpointing
gradient_checkpointing = True

# Maximum gradient normal (gradient clipping)
max_grad_norm = 0.3

# Initial learning rate (AdamW optimizer)
learning_rate = 2e-4

# Weight decay to apply to all layers except bias/LayerNorm weights
weight_decay = 0.001

# Optimizer to use
optim = "paged_adamw_32bit"

# Learning rate schedule
lr_scheduler_type = "cosine"

# Number of training steps (overrides num_train_epochs)
max_steps = -1

# Ratio of steps for a linear warmup (from 0 to learning rate)
warmup_ratio = 0.03

# Group sequences into batches with same length
# Saves memory and speeds up training considerably
group_by_length = True

# Save checkpoint every X updates steps
save_steps = 500

# Log every X updates steps
logging_steps = 25

# %%
# Maximum sequence length to use
max_seq_length = 1000

# Pack multiple short examples in the same input sequence to increase efficiency
packing = False

# Load the entire model on the GPU 0
device_map = {"": 0}

# %%
# Load tokenizer and model with QLoRA configuration
compute_dtype = getattr(torch, bnb_8bit_compute_dtype)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_8bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
)

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map={"": 0}
)
model.config.use_cache = False
model.config.pretraining_tp = 1

# Load LLaMA tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right" # Fix weird overflow issue with fp16 training

for prompt in tqdm(test):
    tmp = {
        "Prompt": "",
        "Original": "",
        "Prediction": ""
    }
    resp = prompt["Text"].split('### Output: ')
    prompt = resp[0]
    pipe = pipeline(task="text-generation", model=model, tokenizer=tokenizer, max_new_tokens=3000)
    result = pipe(f"{prompt}'### Output':")
    result = result[0]['generated_text']
    tmp["Prompt"] = prompt
    tmp["Original"] = resp[1]
    tmp["Prediction"] = result
    dic[opt].append(tmp)
    
del model
del tokenizer
gc.collect()
gc.collect()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 1/2399 [00:54<36:17:25, 54.48s/it]This is a friendly reminder - the current text generation call will exceed the model's predefined maximum length (4096). Depending on the model, you may observe exceptions, performance degradation, or nothing at all.
# 100%|██████████| 2399/2399 [32:53:49<00:00, 49.37s/it]
# 0

# %%
results = {
    "Prompt": [],
    "Original": [],
    "Prediction": []
}

# %%
def format(val):
    val = val.replace("':", "\":")
    val = val.replace("{'", "{\"")
    val = val.replace("',", "\",")
    val = val.replace("'}", "\"}")
    val = val.replace(": '", ": \"")
    val = val.replace(", '", ", \"")
    val = val.replace("}}", "}")
    val = val.replace("\n}", "")
    val = val.replace("\n\n", "\",\"")
    val = val.replace("\n", "")
    val = val.replace("\"t", "'t")
    val = val.replace("\"s", "'s")
    val = val.replace("\\", "/")
    val = re.sub("\d+\" ", "d'", val)
    return val

# %%
def formatting_2(val):
    out = val.split("'### Output':")[1]
    k = val.split("### Keys: ")[1].split("'### Output':")[0].replace('[', '').replace(']','').replace('\n', '').replace('\'', '').split(", ")
    res = {}
    for i, k_ in enumerate(k):
        if len(res) == 0:
            res[k_] = out.replace("\n", "").replace("#", "").split(k_)[1][1:]
        else:
            res[k_] = res[k[i - 1]].split(k_)[1][1:]
            res[k[i - 1]] = res[k[i - 1]].split(k_)[0]
    return res

# %%
def formatting_3(val):
    out = val.split("'### Output':")[1].replace("'", "\"")
    k = val.split("### Keys: ")[1].split("'### Output':")[0].replace('[', '').replace(']','').replace('\n', '').replace('\'', '').split(", ")
    res = {}
    for i, k_ in enumerate(k):
        if len(res) == 0:
            res[k_] = out.replace("\n", "").replace("#", "").split(k_)[1][1:]
        else:
            res[k_] = res[k[i - 1]].split(k_)[1][1:]
            res[k[i - 1]] = res[k[i - 1]].split(k_)[0]
    return res

# %%
ommited = []
a = []
for i, t in enumerate(dic[opt]):
    try:
        val_p = t["Prediction"]
        if "llama" in model_name.lower():
            val_p = formatting_2(val_p)
            val_p = json.dumps(val_p)
        elif "Struct" in model_name:
            val_p = formatting_2(val_p) 
            val_p = json.dumps(val_p)
        else:
            val_p = val_p.split("'### Output':")[1].replace("'", "\"")
            val_p = "{\"Overview\": " + val_p if "{\"" not in val_p and "{'" not in val_p and "{" not in val_p else val_p        
        
        print(val_p, '\n aca termina la review')
        #val_p = format(val_p)
        #val_p = val_p + "\"}" if "\"}" not in val_p else val_p

        val = t["Original"].replace("\"", "'")
        val = format(val)
        results["Prediction"].append(json.loads(val_p))
        results["Original"].append(json.loads(val))
        results["Prompt"].append(t["Prompt"])

    
    except Exception as e:
        ommited.append(i)
        #print(e)
        a.append(t["Prediction"])

print(len(ommited), ommited)
# Out:
# {"Design and Display": ", '", "Battery and Connectivity": "]"}
#  aca termina la review
# {"Design and Display": ": {    \"Screen to Body Ratio\": 92.2,    \"Screen Protection\": \"Gorilla Glass 6\",    \"Water Resistance\": \"IP68, Water resistant (up to 30 minutes in a depth of 1.5 meter)\"  },  \"Hardware\": {    \"Chipset\": \"Qualcomm Snapdragon 888 Plus\",    \"CPU\": [      \" 1 x 3GHz Kryo 680\",      \"3 x 2.42GHz Kryo 680\",      \"4 x 1.8GHz Kryo 680\"    ],    \"GPU\": \"Adreno 660\",    \"Architecture\": \"64-bit\",    \"RAM\": \"12 GB\",    \"Internal Storage\": \"256 GB\",    \"MicroSD Card Slot\": \"No\"  },  \"Main Camera\": {    \"Number of Cameras\": \"Quad\",    \"Resolution\": [      \" 50 MP f/1.57 Wide Angle main camera\",      \"PDAF, OIS, Digital Zoom\",      \"48 MP f/2.2 ultra-wide camera\",      \"12 MP f/1.6 camera\",      \"Optical Zoom\",      \"8 MP f/3.4 camera\",      \"60x Digital Zoom, 5x Optical Zoom, Periscope\"    ],    \"Flash\": \"Dual-color LED Flash\",    \"Video\": [      \" 7680x4320@30fps, 3840x2160@30fps\",      \"1920x1080@30fps\"    ],    \"Features\": [      \"AF Phase Detection\",      \"Auto Flash\",      \"Auto Focus\",      \"Bokeh Effect\",      \"Continuous Shooting\",      \"Exposure compensation\",      \"Face detection\",      \"Geo tagging\",      \"High Dynamic Range mode (HDR)\",      \"ISO control\",      \"ISOCELL Plus\",      \"Laser AF\",      \"Optical image stabilization\",      \"Time Lapse\",      \"Touch to focus\",      \"White balance presets\"    ]  },  \"Front Camera\": {    \"Number of Cameras\": \"Single\",    \"Resolution\": \"32 MP f/2.45, Wide Angle main camera\",    \"Flash\": \"Screen flash\",    \"Video\": [      \"3840x2160@30fps\",      \"1920x1080@30fps\"    ],    \"Features\": [\"Bokeh Effect\"]  },  \"Battery\": {    \"Capacity\": \"4500 mAh\",    \"Type\": \"Li-ion\",    \"Wireless Charging\": \"Yes\",    \"Fast Charging\": \"Yes, Flash\"  },  \"Security & Sensors\": {    \"Fingerprint Sensor\": \"Yes, On-screen\",    \"Sensors\": [\"Light sensor\", \"Proximity sensor\", \"Accelerometer\", \"Compass\", \"Gyroscope\"]  },  \"Connectivity & Audio\": {    \"Network\": [      \"2G\",      \"3G\",      \"4G (compatible with India)\",      \"VoLTE\",      \"5G\"    ],    \"SIM 1 Bands\": {      \"4G Bands\": {        \"TD-LTE\": [          \"2600(band 38) \",          \"2300(band 40) \",          \"2500(band 41) \",          \"2100(band 34) \",          \"1900(band 39) \"        ],        \"FD-LTE\": [          \"2100(band 1) \",          \"1800(band 3) \",          \"2600(band 7) \",          \"900(band 8) \",          \"700(band 28) \",          \"1900(band 2) \",          \"1700(band 4) \",          \"850(band 5) \",          \"700(band 17) \",          \"850(band 18) \",          \"850(band 19) \",          \"800(band 20) \",          \"850(band 26) \"        ]      },      \"3G Bands\": [        \"UMTS 1900 \",        \"2100 \",        \"850 \",        \"900 MHz\"      ],      \"2G Bands\": [        \"GSM 1800 \",        \"1900 \",        \"850 \",        \"900 MHz\"      ],      \"GPRS\": \" Available\",      \"EDGE\": \" Available\"    },    \"SIM card slots\": \"Dual SIM\",    \"SIM card type\": \"Nano + Nano\",    \"Charging Port\": \"USB Type-C\",    \"USB OTG\": \"Yes\",    \"Wi-Fi\": \"Wi-Fi 802.11, a/ac/b/g/n/n 5GHz, MIMO, Mobile Hotspot\",    \"Wi-Fi Calling\": \"\",    \"Bluetooth\": \"Bluetooth 5.2\",    \"NFC\": \"Yes\",    \"GPS\": \"Yes with A-GPS, Glonass\",    \"FM Radio\": \"No\",    \"Loudspeaker\": \"Yes\",    \"3.5mm headphone jack\": \"\"  }} End of output Output:{  \""}
#  aca termina la review
# {"Cameras": "' ", "Performance and Battery": "' General'' Hardware'' Main Camera'' Front Camera'' Battery'' Security & Sensors'' Connectivity & Audio'' Output' Keys: ['"}
#  aca termina la review
# {"Software and Connectivity": " ", "Design and Display": " ", "Battery and Performance": " General: Hardware: Main Camera: Front Camera: Connectivity & Audio: Security & Sensors: "}
#  aca termina la review
# {"Design and Display": " ", "Camera and Storage": " Hardware Security and Sensors Connectivity and Audio Software Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key Features Product Information Reviews Specifications Key Features Product Information Key ...
#  aca termina la review
# {"Design and Display": ":'Waterdrop notch display, 19 9 Aspect Ratio, 270ppi Pixel Density, Multi-touch Touch Screen, IPS LCD, 2.5D Curved Glass, Corning Gorilla Glass v5, 64 GB Internal Storage, Up to 512 GB MicroSD Card Slot, 6.22 inches (15.8 cm) Size, 720 x 1520 pixels Resolution, 270ppi Pixel Density, 1 GB RAM, 3 GB Chipset, Qualcomm Snapdragon 439, 4 x 1.95GHz Cortex A53, 4 x 1.45GHz Cortex A53, Adreno 505, 64-bit, 3 GB, 64 GB, Dual 13 MP f/2.2 main camera, PDAF, Digital Zoom, 2 MP f/2.4 depth sensor, LED Flash, 1920x1080@30fps, 1280x720@30fps, AF Phase Detection, Artificial Intelligence, Auto Flash, Auto Focus, Bokeh Effect, CMOS image sensor, Continuous Shooting, Exposure compensation, Face detection, Geo tagging, High Dynamic Range mode (HDR), ISO control, Touch to focus, White balance presets, 8 MP f/2.0 main camera, LED Flash, 1920x1080@30fps, Fast Charging, Li-Polymer, Light sensor, Proximity sensor, Accelerometer, Compass, 2G, 3G, 4G (compatible with India), VoLTE, TD-LTE, FD-LTE, UMTS 1900, 2100, 850, 900 MHz, GSM 1800, 1900, 850, 900 MHz, GPRS, EDGE, Wi-Fi 802.11, b/g/n,  Direct, Mobile Hotspot, Bluetooth 4.2, NFC, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Yes with A-GPS, Glonass, Ye ...
#  aca termina la review
# {"Software and Connectivity": ", '", "Battery and Performance": ", '", "Design and Display": "]"}
#  aca termina la review
# {"Software and Connectivity": ": {'Operating System': 'Android 6.0 (Marshmallow)', 'Custom UI': '', 'Dimensions': '150mm x 72mm x 9mm', 'Weight': '187g', 'Display & Design': {'Size': '5.5 inches (13.97 cm)', 'Resolution': '480 x 1014 pixels', 'Pixel Density': '204ppi', 'Touch Screen': 'Yes, Capacitive Touchscreen, Multi-touch', 'Type': 'IPS LCD', 'Screen To Body Ratio': '', 'Aspect Ratio': '', 'Refresh Rate': '', 'Screen Protection': '', 'Design': 'Waterdrop notch display', 'Colour Options': ['Blue'], 'Water Resistance': ''}, 'Hardware': {'Chipset': '', 'CPU': [' 4 x 1.3GHz'], 'GPU': '', 'Architecture': '', 'RAM': '4 GB', 'Internal Storage': '64 GB', 'MicroSD Card Slot': 'Up to 64 GB'}, 'Main Camera': {'Number of Cameras': 'Single', 'Resolution': [' 8 MP main camera', 'Digital Zoom'], 'Flash': 'LED Flash', 'Video': [], 'Features': [',']}, 'Front Camera': {'Number of Cameras': 'Single', 'Resolution': '5 MP main camera', 'Flash': 'LED Flash', 'Video': [','], 'Features': [',']}, 'Battery': {'Capacity': '3000 mAh', 'Type': 'Li-ion', 'Wireless Charging': '', 'Fast Charging': ''}, 'Security & Sensors': {'Fingerprint Sensor': 'No', 'Sensors': ['Light sensor', 'Proximity sensor', 'Accelerometer']}, 'Connectivity & Audio': {'Network': ['2G', '3G', '4G (compatible with India)', 'VoLTE'], 'SIM 1 Bands': {'4G Bands': {'TD-LTE': ['2300(band 40)'], 'FD-LTE': ['1800(band 3)']}, '3G Bands': ['UMTS 1900 ', '2100 ', '850 ', '900 MHz'], '2G Bands': ['GSM 1800 ', '1900 ', '850 ', '900 MHz'], 'GPRS':'Available', 'EDGE':'Available'}, 'SIM card slots': 'Dual SIM', 'SIM card type': '', 'Charging Port':'microUSB', 'USB OTG': '', 'Wi-Fi': 'Wi-Fi 802.11, b/g/n, Mobile Hotspot', 'Wi-Fi Calling': '', 'Bluetooth': 'Bluetooth', 'NFC': '', 'GPS': 'Yes with A-GPS', 'FM Radio': '', 'Loudspeaker': 'Yes', '3.5mm headphone jack': 'Yes'}} ", "Design and Display": " {'Size': '5.5 inches (13.97 cm)', 'Resolution': '480 x 1014 pixels', 'Pixel Density': '204ppi', 'Touch Screen': 'Yes, Capacitive Touchscreen, Multi-touch', 'Type': 'IPS LCD', 'Screen To Body Ratio': '', 'Aspect Ratio': '', 'Refresh Rate': '', 'Screen Protection': '', 'Design': 'Waterdrop notch display', 'Colour Options': ['Blue'], 'Water Resistance': ''} Main Camera: {'Number of Cameras': 'Single', 'Resolution': [' 8 MP main camera', 'Digital Zoom'], 'Flash': 'LED Flash', 'Video': [], 'Features': [',']} "}
#  aca termina la review
# {"Design and Display": ": {'Operating System': 'No', 'Custom UI': 'No', 'Dimensions': '134mm x 56.4mm x 13.8mm', 'Weight': '58g'}, '", "Software and Platform": ": {'Chipset': 'Qualcomm Snapdragon 205 MSM8905', 'CPU': [' 2 x 1.1GHz Cortex A7'], 'GPU': 'Adreno 304', 'Architecture': '', 'RAM': '512 MB', 'Internal Storage': '4 GB', 'MicroSD Card Slot': 'Up to 32 GB'}, 'Main Camera': {'Number of Cameras': 'Single', 'Resolution': [' 2 MP main camera', 'Digital Zoom'], 'Flash': '', 'Video': [], 'Features': [',']}, 'Front Camera': {'Number of Cameras': 'Single', 'Resolution': '0.3 MP main camera', 'Flash': '', 'Video': [','], 'Features': [',']}, 'Battery': {'Capacity': '2000 mAh', 'Type': 'Li-ion', 'Wireless Charging': 'No', 'Fast Charging': 'No'}, 'Security & Sensors': {'Fingerprint Sensor': 'No', 'Sensors': [',']}, 'Connectivity & Audio': {'Network': ['2G', '3G', '4G (compatible with India)', 'VoLTE'], 'SIM 1 Bands': {'4G Bands': {'TD-LTE': ['2300(band 40)'], 'FD-LTE': ['1800(band 3)']}, '3G Bands': ['UMTS 2100 ', '900 MHz'], '2G Bands': ['GSM 1800 ', '900 MHz'], 'GPRS':'Available', 'EDGE':'Available'}, 'SIM card slots': 'Dual SIM', 'SIM card type': 'Micro + Micro', 'Charging Port': '', 'USB OTG': '', 'Wi-Fi': 'Wi-Fi 802.11, b/g/n, Mobile Hotspot', 'Wi-Fi Calling': '', 'Bluetooth': 'Bluetooth 4.1', 'NFC': 'No', 'GPS': '', 'FM Radio': 'Yes', 'Loudspeaker': 'Yes', '3.5mm headphone jack': 'Yes'}} Keys: ['"}
#  aca termina la review
# {"Software and Connectivity": ", '", "Cameras": ", '", "Design and Display": "] "}
#  aca termina la review
# {"Design and Display": " ", "Battery and Performance": " Hardware: Main Camera: Front Camera: Connectivity & Audio: Security & Sensors: Network: SIM card slots: SIM card type: Charging Port: USB OTG: Wi-Fi: Wi-Fi Calling: Bluetooth: NFC: GPS: FM Radio: Loudspeaker: 3.5mm headphone jack: Output: Product: {'Model Name': 'Tecno Camon 16', 'General': {'Operating System': 'Android 10 (Q)', 'Custom UI': '', 'Dimensions': '170.9mm x 77.2mm x 9.2mm', 'Weight': '207g'}, 'Display & Design': {'Size': '6.8 inches (17.27 cm)', 'Resolution': '720 x 1640 pixels', 'Pixel Density': '263ppi', 'Touch Screen': 'Yes, Capacitive Touchscreen, Multi-touch', 'Type': 'TFT', 'Screen To Body Ratio': '89.1 %', 'Aspect Ratio': '20.5 9', 'Refresh Rate': '', 'Screen Protection': '', 'Design': 'Punch-hole display', 'Colour Options': ['Cloud White', 'Purist Blue'], 'Water Resistance': ''}, 'Hardware': {'Chipset': 'MediaTek Helio G70', 'CPU': [' 2 x 2GHz Cortex A76', '6 x 1.7GHz Cortex A55'], 'GPU': 'Mali-G52', 'Architecture': '64-bit', 'RAM': '4 GB', 'Internal Storage': '64 GB', 'MicroSD Card Slot': 'Up to 256 GB'}, 'Main Camera': {'Number of Cameras': 'Triple', 'Resolution': [' 64 MP f/1.79 Wide Angle main camera', 'Digital Zoom, 79\u00b0 field-of-view', '2 MP f/2.4 depth sensor', '2 MP f/2.4 macro sensor'], 'Flash': 'Penta LED Flash', 'Video': [], 'Features': ['Artificial Intelligence', 'Auto Flash', 'Auto Focus', 'Bokeh Effect', 'Continuous Shooting', 'Exposure compensation', 'Face detection', 'Geo tagging', 'High Dynamic Range mode (HDR)', 'ISO control', 'Touch to focus', 'White balance presets']}, 'Front Camera': {'Number of Cameras': 'Single', 'Resolution': '16 MP f/2.0, Wide Angle main camera', 'Flash': 'Dual LED', 'Video': [','], 'Features': ['Artificial Intelligence', 'Bokeh Effect', 'High Dynamic Range mode (HDR)']}, 'Battery': {'Capacity': '5000 mAh', 'Type': 'Li-Polymer', 'Wireless Charging': '', 'Fast Charging': 'Yes, Flash'}, 'Security & Sensors': {'Fingerprint Sensor': 'Yes, Rear', 'Sensors': ['Light sensor', 'Proximity sensor', 'Accelerometer', 'Compass']}, 'Connectivity & Audio': {'Network': ['2G', '3G', '4G (compatible with India)', 'VoLTE'], 'SIM 1 Bands': {'4G Bands': {'TD-LTE': ['2600(band 38) ', '2300(band 40) ', '2500(band 41)'], 'FD-LTE': ['2100(band 1) ', '1800(band 3) ', '2600(band 7) ', '900(band 8) ', '850(band 5) ', '800(band 20)']}, '3G Bands': ['UMTS 1900 ', '2100 ', '850 ', '900 MHz'], '2G Bands': ['GSM 1800 ', '1900 ', '850 ', '900 MHz'], 'GPRS':'Available', 'EDGE':'Available'}, 'SIM card slots': 'Dual SIM', 'SIM card type': 'Nano + Nano', 'Charging Port':'microUSB 2.0', 'USB OTG': 'Yes', 'Wi-Fi': 'Wi-Fi 802.11, ac/b/g/n/n 5GHz, Mobile Hotspot', 'Wi-Fi Calling': '', 'Bluetooth': 'Bluetooth 5.0', 'NFC': 'No', 'GPS': 'Yes with A-GPS, Glonass', 'FM Radio': 'Yes', 'Loudspeaker': 'Yes', '3.5mm headphone jack': 'Yes'}} Keys: ['Display and Design', '"}
#  aca termina la review
# {"Camera and Storage": ", '", "Battery and Connectivity": "]"}
#  aca termina la review
# {"Battery and Performance": ", '", "Design and Display": "] "}
#  aca termina la review
# {"Battery and Connectivity": " Battery: Capacity: '3090 mAh' Type: 'Li-ion' Wireless Charging: 'No' Fast Charging: 'Yes, Quick, v3.0' Connectivity & Audio: Network: SIM 1 Bands: 3G Bands: 2G Bands: Charging Port: 'USB Type-C' USB OTG: 'Yes' Wi-Fi: Wi-Fi Calling: Bluetooth: NFC: GPS: FM Radio: Loudspeaker: 3.5mm headphone jack: 'Yes' General: Display & Design: Hardware: Main Camera: Front Camera: Security & Sensors: Software: Product: Model Name: 'Nokia 8' General: Operating System: 'Android 7.1.1 (Nougat)', 'Custom UI': 'Stock', 'Dimensions': '151.5mm x 73.7mm x 7.9mm', 'Weight': '160g' Display & Design: Size: '5.3 inches (13.46 cm)' Resolution: '1440 x 2560 pixels' Pixel Density: '554ppi' Touch Screen: 'Yes, Capacitive Touchscreen, Multi-touch' Type: 'IPS LCD, 2.5D Curved Glass' Screen To Body Ratio: '' Aspect Ratio: '16 9' Refresh Rate: '' Screen Protection: 'Corning Gorilla Glass v5' Design: '' Colour Options: ['Polished Blue', 'Tempered Blue', 'Steel', 'Polished Copper'], 'Water Resistance': 'IP54, Splash proof' Hardware: Chipset: 'Qualcomm Snapdragon 835 MSM8998', 'CPU': [' 4 x 2.45GHz Kryo 280', '4 x 1.8GHz Kryo 280'], 'GPU': 'Adreno 540', 'Architecture': '64-bit', 'RAM': '4 GB', 'Internal Storage': '64 GB', 'MicroSD Card Slot': 'Up to 256 GB' Main Camera: Number of Cameras: 'Dual', 'Resolution': [' 13 MP f/2.0 main camera', 'PDAF, OIS, Digital Zoom', '13 MP f/2.0 camera'], 'Flash': 'Dual-color LED Flash', 'Video': [' 3840x2160@30fps, 1920x1080@30fps'], 'Features': ['AF Phase Detection', 'Auto Flash', 'Auto Focus', 'CMOS image sensor', 'Continuous Shooting', 'Exposure compensation', 'Face detection', 'Geo tagging', 'High Dynamic Range mode (HDR)', 'ISO control', 'Laser AF', 'Optical image stabilization', 'Self-timer', 'Touch to focus', 'White balance presets'] Front Camera: Number of Cameras: 'Single', 'Resolution': '13 MP f/2.0 main camera', 'Flash': 'Screen flash', 'Video': ['1920x1080@30fps'], 'Features': [','] Battery: Capacity: '3090 mAh' Type: 'Li-ion' Wireless Charging: 'No' Fast Charging: 'Yes, Quick, v3.0' Connectivity & Audio: Network: SIM 1 Bands: 3G Bands: 2G Bands: Charging Port: 'USB Type-C' USB OTG: 'Yes' Wi-Fi: Wi-Fi Calling: Bluetooth: NFC: GPS: FM Radio: Loudspeaker: 3.5mm headphone jack: 'Yes' General: Display & Design: Hardware: Main Camera: Front Camera: Security & Sensors: Software: Product: Model Name: 'Nokia 8' General: Operating System: 'Android 7.1.1 (Nougat)', 'Custom UI': 'Stock', 'Dimensions': '151.5mm x 73.7mm x 7.9mm', 'Weight': '160g' Display & Design: Size: '5.3 inches (13.46 cm)' Resolution: '1440 x 2560 pixels' Pixel Density: '554ppi' Touch Screen: 'Yes, Capacitive Touchscreen, Multi-touch' Type: 'IPS LCD, 2.5D Curved Glass' Screen To Body Ratio: '' Aspect Ratio: '16 9' Refresh Rate: '' Screen Protection: 'Corning Gorilla Glass v5' Design: '' Colour Options: ['Polished Blue', 'Tempered Blue', 'Steel', 'Polished Copper'], 'Water Resistance': 'IP54, Splash proof' Hardware: Chipset: 'Qualcomm Snapdragon 835 MSM8998', 'CPU': [' 4 x 2.45GHz Kryo 280', '4 x 1.8GHz Kryo 280'], 'GPU': 'Adreno 540', 'Architecture': '64-bit', 'RAM': '4 GB', 'Internal Storage': '64 GB', 'MicroSD Card Slot': 'Up to 256 GB' Main Camera: Number of Cameras: 'Dual', 'Resolution': [' 13 MP f/2.0 main camera', 'PDAF, OIS, Digital Zoom', '13 MP f/2.0 camera'], 'Flash': 'Dual-color LED Flash', 'Video': [' 3840x2160@30fps, 1920x1080@30fps'], 'Features': ['AF Phase Detection', 'Auto Flash', 'Auto Focus', 'CMOS image sensor', 'Continuous Shooting', 'Exposure compensation', 'Face detection', 'Geo tagging', 'High Dynamic Range mode (HDR)', 'ISO control', 'Laser AF', 'Optical image stabilization', 'Self-timer', 'Touch to focus', 'White balance presets'] Front Camera: Number of Cameras: 'Single', 'Resolution': '13 MP f/2.0 main camera', 'Flash': 'Screen flash', 'Video': ['1920x1080@30fps'], 'Features': [','] Battery: Capacity: '3090 mAh' Type: 'Li-ion' Wireless Charging: 'No' Fast Charging: 'Yes, Quick, v3.0' Connectivity & Audio ...
#  aca termina la review
# {"Battery and Performance": ", '", "Cameras": ", '", "Software and Connectivity": "] Product: {'Model Name': 'Huawei Mate 60', 'General': {'Operating System': 'HarmonyOS', 'Custom UI': '', 'Dimensions': '161.4mm x 76mm x 7.9mm', 'Weight': '209g'}, 'Display & Design': {'Size': '6.69 inches (16.99 cm)', 'Resolution': '1216 x 2688 pixels', 'Pixel Density': '441ppi', 'Touch Screen': 'Yes, Capacitive Touchscreen, Multi-touch', 'Type': 'OLED', 'Screen To Body Ratio': '', 'Aspect Ratio': '', 'Refresh Rate': '120Hz', 'Screen Protection': '', 'Design': 'Punch-hole display', 'Colour Options': ['Black', 'Green', 'Purple', 'White'], 'Water Resistance': 'IP68, Water resistant (up to 30 minutes in a depth of 4 meter)'}, 'Hardware': {'Chipset': 'HiSilicon Kirin 9000E', 'CPU': [' 1 x 2.62GHz', '3 x 2.15GHz', '4 x 1.53GHz Cortex A510'], 'GPU': '', 'Architecture': '64-bit', 'RAM': '12 GB', 'Internal Storage': '256 GB', 'MicroSD Card Slot': 'Up to 256 GB'}, 'Main Camera': {'Number of "}
#  aca termina la review
# {"Camera and Storage": "' ", "Battery and Connectivity": " Product: {'Model Name': 'InFocus EPIC 1', 'General': {'Operating System': 'Android 6.0 (Marshmallow)', 'Custom UI': 'InLife UI', 'Dimensions': '153mm x 76mm x 8.4mm', 'Weight': '160g'}, 'Display & Design': {'Size': '5.5 inches (13.97 cm)', 'Resolution': '1080 x 1920 pixels', 'Pixel Density': '401ppi', 'Touch Screen': 'Yes, Capacitive Touchscreen, Multi-touch', 'Type': 'IPS LCD', 'Screen To Body Ratio': '', 'Aspect Ratio': '', 'Refresh Rate': '', 'Screen Protection': 'Corning Gorilla Glass', 'Design': '', 'Colour Options': ['Gold'], 'Water Resistance': ''}, 'Hardware': {'Chipset': 'MediaTek MT6797M', 'CPU': [' 2 x 2GHz Cortex A72', '4 x 1.85GHz Cortex A53', '4 x 1.4GHz Cortex A53'], 'GPU': 'Mali-T880 MP4', 'Architecture': '64-bit', 'RAM': '3 GB', 'Internal Storage': '32 GB', 'MicroSD Card Slot': 'Up to 128 GB'}, 'Main Camera': {'Number of Cameras': 'Single', 'Resolution': [' 16 MP f/2.0 main camera', 'PDAF, Digital Zoom'], 'Flash': 'Dual-color LED Flash', 'Video': [' 3840x2160@30fps'], 'Features': ['AF Phase Detection', 'Auto Flash', 'Auto Focus', 'CMOS image sensor', 'Continuous Shooting', 'Exposure compensation', 'Face detection', 'Geo tagging', 'High Dynamic Range mode (HDR)', 'ISO control', 'Self-timer', 'Touch to focus', 'White balance presets']}, 'Front Camera': {'Number of Cameras': 'Single', 'Resolution': '8 MP f/1.8 main camera', 'Flash': '', 'Video': [','], 'Features': [',']}, 'Battery': {'Capacity': '3000 mAh', 'Type': 'Li-Polymer', 'Wireless Charging': 'No', 'Fast Charging': 'Yes'}, 'Security & Sensors': {'Fingerprint Sensor': 'Yes, Rear', 'Sensors': ['Light sensor', 'Proximity sensor', 'Accelerometer', 'Compass']}, 'Connectivity & Audio': {'Network': ['2G', '3G', '4G (compatible with India)', 'VoLTE'], 'SIM 1 Bands': {'4G Bands': {'TD-LTE': ['2600(band 38) ', '2300(band 40) ', '2500(band 41) ', '1900(band 39)'], 'FD-LTE': ['2100(band 1) ', '1800(band 3) ', '2600(band 7) ', '900(band 8) ', '700(band 28) ', '850(band 5)']}, '3G Bands': ['UMTS 2100 ', '900 MHz'], '2G Bands': ['GSM 1800 ', '1900 ', '850 ', '900 MHz'], 'GPRS':'Available', 'EDGE':'Available'}, 'SIM card slots': 'Dual SIM', 'SIM card type': 'Nano + Nano', 'Charging Port': 'USB Type-C', 'USB OTG': '', 'Wi-Fi': 'Wi-Fi 802.11, a/ac/b/g/n/n 5GHz, Mobile Hotspot', 'Wi-Fi Calling': '', 'Bluetooth': 'Bluetooth 4.1', 'NFC': 'No', 'GPS': 'Yes with A-GPS, Glonass', 'FM Radio': 'Yes', 'Loudspeaker': 'Yes', '3.5mm headphone jack': 'Yes'}} Keys: ['"}
#  aca termina la review
# {"Design and Display": " '", "Camera and Storage": " 'Hardware' 'Main Camera' 'Front Camera' 'Battery' 'Security & Sensors' 'Connectivity & Audio' 'Software' 'Network' 'SIM 1 Bands' 'SIM card slots' 'SIM card type' 'Charging Port' 'USB OTG' 'Wi-Fi' 'Wi-Fi Calling' 'Bluetooth' 'NFC' 'GPS' 'FM Radio' 'Loudspeaker' '3.5mm headphone jack' 'Product' 'General' 'Hardware' 'Main Camera' 'Front Camera' 'Battery' 'Security & Sensors' 'Connectivity & Audio' 'Software' 'Network' 'SIM 1 Bands' 'SIM card slots' 'SIM card type' 'Charging Port' 'USB OTG' 'Wi-Fi' 'Wi-Fi Calling' 'Bluetooth' 'NFC' 'GPS' 'FM Radio' 'Loudspeaker' '3.5mm headphone jack' 'Product' 'General' 'Hardware' 'Main Camera' 'Front Camera' 'Battery' 'Security & Sensors' 'Connectivity & Audio' 'Software' 'Network' 'SIM 1 Bands' 'SIM card slots' 'SIM card type' 'Charging Port' 'USB OTG' 'Wi-Fi' 'Wi-Fi Calling' 'Bluetooth' 'NFC' 'GPS' 'FM Radio' 'Loudspeaker' '3.5mm headphone jack' 'Product' 'General' 'Hardware' 'Main Camera' 'Front Camera' 'Battery' 'Security & Sensors' 'Connectivity & Audio' 'Software' 'Network' 'SIM 1 Bands' 'SIM card slots' 'SIM card type' 'Charging Port' 'USB OTG' 'Wi-Fi' 'Wi-Fi Calling' 'Bluetooth' 'NFC' 'GPS' 'FM Radio' 'Loudspeaker' '3.5mm headphone jack' 'Product' 'General' 'Hardware' 'Main Camera' 'Front Camera' 'Battery' 'Security & Sensors' 'Connectivity & Audio' 'Software' 'Network' 'SIM 1 Bands' 'SIM card slots' 'SIM card type' 'Charging Port' 'USB OTG' 'Wi-Fi' 'Wi-Fi Calling' 'Bluetooth' 'NFC' 'GPS' 'FM Radio' 'Loudspeaker' '3.5mm headphone jack' 'Product' 'General' 'Hardware' 'Main Camera' 'Front Camera' 'Battery' 'Security & Sensors' 'Connectivity & Audio' 'Software' 'Network' 'SIM 1 Bands' 'SIM card slots' 'SIM card type' 'Charging Port' 'USB OTG' 'Wi-Fi' 'Wi-Fi Calling' 'Bluetooth' 'NFC' 'GPS' 'FM Radio' 'Loudspeaker' '3.5mm headphone jack' 'Product' 'General' 'Hardware' 'Main Camera' 'Front Camera' 'Battery' 'Security & Sensors' 'Connectivity & Audio' 'Software' 'Network' 'SIM 1 Bands' 'SIM card slots' 'SIM card type' 'Charging Port' 'USB OTG' 'Wi-Fi' 'Wi-Fi Calling' 'Bluetooth' 'NFC' 'GPS' 'FM Radio' 'Loudspeaker' '3.5mm headphone jack' 'Product' 'General' 'Hardware' 'Main Camera' 'Front Camera' 'Battery' 'Security & Sensors' 'Connectivity & Audio' 'Software' 'Network' 'SIM 1 Bands' 'SIM card slots' 'SIM card type' 'Charging Port' 'USB OTG' 'Wi-Fi' 'Wi-Fi Calling' 'Bluetooth' 'NFC' 'GPS' 'FM Radio' 'Loudspeaker' '3.5mm headphone jack' 'Product' 'General' 'Hardware' 'Main Camera' 'Front Camera' 'Battery' 'Security & Sensors' 'Connectivity & Audio' 'Software' 'Network' 'SIM 1 Bands' 'SIM card slots' 'SIM card type' 'Charging Port' 'USB OTG' 'Wi-Fi' 'Wi-Fi Calling' 'Bluetooth' 'NFC' 'GPS' 'FM Radio' 'Loudspeaker' '3.5mm headphone jack' 'Product' 'General' 'Hardware' 'Main Camera' 'Front Camera' 'Battery' 'Security & Sensors' 'Connectivity & Audio' 'Software' 'Network' 'SIM 1 Bands' 'SIM card slots' 'SIM card type' 'Charging Port' 'USB OTG' 'Wi-Fi' 'Wi-Fi Calling' 'Bluetooth' 'NFC' 'GPS' 'FM Radio' 'Loudspeaker' '3.5mm headphone jack' 'Product' 'General' 'Hardware' 'Main Camera' 'Front Camera' 'Battery' 'Security & Sensors' 'Connectivity & Audio' 'Software' 'Network' 'SIM 1 Bands' 'SIM card slots' 'SIM card type' 'Charging Port' 'USB OTG' 'Wi-Fi' 'Wi-Fi Calling' 'Bluetooth' 'NFC' 'GPS' 'FM Radio' 'Loudspeaker' '3.5mm headphone jack' 'Product' 'General' 'Hardware' 'Main Camera' 'Front Camera' 'Battery' 'Security & Sensors' 'Connectivity & Audio' 'Software' 'Network' 'SIM 1 Bands' 'SIM card slots' 'SIM card type' 'Charging Port' 'USB OTG' 'Wi-Fi' 'Wi-Fi Calling' 'Bluetooth' 'NFC' 'GPS' 'FM Radio' 'Loudspeaker' '3.5mm headphone jack' 'Product' 'General' 'Hardware' 'Main Camera' 'Front Camera' 'Battery' 'Security & Sensors' 'Connectivity & Audio' 'Software' 'Network' 'SIM 1 Bands' 'SIM card slots' 'SIM card type' 'Charging Port' 'USB OTG' 'Wi-Fi' 'Wi-Fi Calling' 'Bluetooth' 'NFC' 'GPS' 'FM Radio' 'Loudspeaker' '3.5mm headphone jack' 'Product' 'Gene ...
#  aca termina la review
# {"Cameras": ": 'Single', 'Resolution': [' 8 MP f/2.0 main camera', 'Digital Zoom'], 'Flash': 'Dual LED Flash', 'Video': [' 1920x1080@30fps'], 'Features': ['Artificial Intelligence', 'Auto Flash', 'Auto Focus', 'Bokeh Effect', 'Continuous Shooting', 'Exposure compensation', 'Face detection', 'High Dynamic Range mode (HDR)', 'Touch to focus', 'White balance presets']}, 'Front Camera': {'Number of "}
#  aca termina la review
# {"Software and Connectivity": "The Vivo Y12G comes with Funtouch OS 11.1 out of the box. The operating system is Android 11. The phone is powered by an octa-core Qualcomm Snapdragon 439 processor. The phone packs 3 GB of RAM and 32 GB of internal storage that can be expanded via a microSD card.The Vivo Y12G packs a 6.51-inch IPS LCD panel with a resolution of 720 x 1600 pixels and a pixel density of 270 pixels per inch (ppi). The screen-to-body ratio is 89%.The Vivo Y12G is powered by a 5000mAh battery. The battery supports fast charging.The Vivo Y12G runs on Android 11 and is powered by a 5000mAh battery. The Vivo Y12G supports proprietary fast charging.As far as the cameras are concerned, the Vivo Y12G on the rear packs a 13-megapixel primary camera; an 8-megapixel front shooter for selfies.The Vivo Y12G runs on Android 11 and is powered by a 5000mAh battery. The Vivo Y12G supports proprietary fast charging.As far as the cameras are concerned, the Vivo Y12G on the rear packs a 13-megapixel primary camera; an 8-megapixel front shooter for selfies.The Vivo Y12G runs on Android 11 and is powered by a 5000mAh battery. The Vivo Y12G supports proprietary fast charging.As far as the cameras are concerned, the Vivo Y12G on the rear packs a 13-megapixel primary camera; an 8-megapixel front shooter for selfies.The Vivo Y12G runs on Android 11 and is powered by a 5000mAh battery. The Vivo Y12G supports proprietary fast charging.As far as the cameras are concerned, the Vivo Y12G on the rear packs a 13-megapixel primary camera; an 8-megapixel front shooter for selfies.The Vivo Y12G runs on Android 11 and is powered by a 5000mAh battery. The Vivo Y12G supports proprietary fast charging.As far as the cameras are concerned, the Vivo Y12G on the rear packs a 13-megapixel primary camera; an 8-megapixel front shooter for selfies.The Vivo Y12G runs on Android 11 and is powered by a 5000mAh battery. The Vivo Y12G supports proprietary fast charging.As far as the cameras are concerned, the Vivo Y12G on the rear packs a 13-megapixel primary camera; an 8-megapixel front shooter for selfies.The Vivo Y12G runs on Android 11 and is powered by a 5000mAh battery. The Vivo Y12G supports proprietary fast charging.As far as the cameras are concerned, the Vivo Y12G on the rear packs a 13-megapixel primary camera; an 8-megapixel front shooter for selfies.The Vivo Y12G runs on Android 11 and is powered by a 5000mAh battery. The Vivo Y12G supports proprietary fast charging.As far as the cameras are concerned, the Vivo Y12G on the rear packs a 13-megapixel primary camera; an 8-megapixel front shooter for selfies.The Vivo Y12G runs on Android 11 and is powered by a 5000mAh battery. The Vivo Y12G supports proprietary fast charging.As far as the cameras are concerned, the Vivo Y12G on the rear packs a 13-megapixel primary camera; an 8-megapixel front shooter for selfies.The Vivo Y12G runs on Android 11 and is powered by a 5000mAh battery. The Vivo Y12G supports proprietary fast charging.As far as the cameras are concerned, the Vivo Y12G on the rear packs a 13-megapixel primary camera; an 8-megapixel front shooter for selfies.The Vivo Y12G runs on Android 11 and is powered by a 5000mAh battery. The Vivo Y12G supports proprietary fast charging.As far as the cameras are concerned, the Vivo Y12G on the rear packs a 13-megapixel primary camera; an 8-megapixel front shooter for selfies.The Vivo Y12G runs on Android 11 and is powered by a 5000mAh battery. The Vivo Y12G supports proprietary fast charging.As far as the cameras are concerned, the Vivo Y12G on the rear packs a 13-megapixel primary camera; an 8-megapixel front shooter for selfies.The Vivo Y12G runs on Android 11 and is powered by a 5000mAh battery. The Vivo Y12G supports proprietary fast charging.As far as the cameras are concerned, the Vivo Y12G on the rear packs a 13-megapixel primary camera; an 8-megapixel front shooter for selfies.The Vivo Y12G runs on Android 11 and is powered by a 5000mAh battery. The Vi ...
#  aca termina la review
# {"Battery and Connectivity": ": {'Battery': {'Capacity': '4000 mAh', 'Type': 'Li-Polymer', 'Wireless Charging': 'No', 'Fast Charging': 'No'}, 'Connectivity & Audio': {'Network': ['2G', '3G', '4G (compatible with India)', 'VoLTE'], 'SIM 1 Bands': {'4G Bands': {'TD-LTE': ['2300(band 40) ', '2500(band 41)'], 'FD-LTE': ['2100(band 1) ', '1800(band 3) ', '850(band 5)']}, '3G Bands': ['UMTS 1900 ', '2100 ', '850 ', '900 MHz'], '2G Bands': ['GSM 1800 ', '1900 ', '850 ', '900 MHz'], 'GPRS':'Available', 'EDGE':'Available'}, 'SIM card slots': 'Dual SIM', 'SIM card type': 'Nano + Nano (Hybrid)', 'Charging Port':'microUSB 2.0', 'USB OTG': 'Yes', 'Wi-Fi': 'Wi-Fi 802.11, a/b/g/n/n 5GHz,  Direct, Mobile Hotspot', 'Wi-Fi Calling': '', 'Bluetooth': 'Bluetooth 4.2', 'NFC': 'No', 'GPS': 'Yes with A-GPS, Glonass', 'FM Radio': '', 'Loudspeaker': 'Yes', '3.5mm headphone jack': 'Yes'}} Product: {'Model Name': 'Xiaomi Redmi Note 5', 'General': {'Operating System': 'Android 7.1.2 (Nougat)', 'Custom UI': 'MIUI', 'Dimensions': '158.5mm x 75.4mm x 8mm', 'Weight': '180g'}, 'Display & Design': {'Size': '5.99 inches (15.21 cm)', 'Resolution': '1080 x 2160 pixels', 'Pixel Density': '403ppi', 'Touch Screen': 'Yes, Capacitive Touchscreen, Multi-touch', 'Type': 'IPS LCD, 2.5D Curved Glass', 'Screen To Body Ratio': '', 'Aspect Ratio': '18 9', 'Refresh Rate': '', 'Screen Protection': 'Corning Gorilla Glass', 'Design': '', 'Colour Options': ['Black', 'Gold', 'Rose Gold', 'Lake Blue'], 'Water Resistance': ''}, 'Hardware': {'Chipset': 'Qualcomm Snapdragon 625 MSM8953', 'CPU': [' 8 x 2GHz Cortex A53'], 'GPU': 'Adreno 506', 'Architecture': '64-bit', 'RAM': '3 GB', 'Internal Storage': '32 GB', 'MicroSD Card Slot': 'Up to 128 GB'}, 'Main Camera': {'Number of Cameras': 'Single', 'Resolution': [' 12 MP f/2.2 main camera', 'PDAF, Digital Zoom'], 'Flash': 'Dual-color LED Flash', 'Video': [' 1920x1080@30fps'], 'Features': ['AF Phase Detection', 'Auto Flash', 'Auto Focus', 'CMOS image sensor', 'Continuous Shooting', 'Exposure compensation', 'Face detection', 'Geo tagging', 'High Dynamic Range mode (HDR)', 'ISO control', 'Self-timer', 'Touch to focus', 'White balance presets']}, 'Front Camera': {'Number of Cameras': 'Single', 'Resolution': '5 MP f/2.0 main camera', 'Flash': 'LED Flash', 'Video': ['1920x1080@30fps'], 'Features': ['Face detection', 'Self-timer']}, 'Battery': {'Capacity': '4000 mAh', 'Type': 'Li-Polymer', 'Wireless Charging': 'No', 'Fast Charging': 'No'}, 'Security & Sensors': {'Fingerprint Sensor': 'Yes, Rear', 'Sensors': ['Light sensor', 'Proximity sensor', 'Accelerometer', 'Compass', 'Gyroscope']}, 'Connectivity & Audio': {'Network': ['2G', '3G', '4G (compatible with India)', 'VoLTE'], 'SIM 1 Bands': {'4G Bands': {'TD-LTE': ['2300(band 40) ', '2500(band 41)'], 'FD-LTE': ['2100(band 1) ', '1800(band 3) ', '850(band 5)']}, '3G Bands': ['UMTS 1900 ', '2100 ', '850 ', '900 MHz'], '2G Bands': ['GSM 1800 ', '1900 ', '850 ', '900 MHz'], 'GPRS':'Available', 'EDGE':'Available'}, 'SIM card slots': 'Dual SIM', 'SIM card type': 'Nano + Nano (Hybrid)', 'Charging Port':'microUSB 2.0', 'USB OTG': 'Yes', 'Wi-Fi': 'Wi-Fi 802.11, a/b/g/n/n 5GHz,  Direct, Mobile Hotspot', 'Wi-Fi Calling': '', 'Bluetooth': 'Bluetooth 4.2', 'NFC': 'No', 'GPS': 'Yes with A-GPS, Glonass', 'FM Radio': '', 'Loudspeaker': 'Yes', '3.5mm headphone jack': 'Yes'}} Keys: ['"}
#  aca termina la review
# {"Design and Display": "]\\end{code}Comment: What's the problem with this?Comment: @MohamedAli I think OP is using the JSON format to store the data, and wants to write it back to a file in the same format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I have a json file which contains specifications of a product. I want to write the product specifications in a json format.Comment: @MohamedAli, I  ...
#  aca termina la review
# {"Battery and Performance": " ", "Design and Display": " General' Main Camera' Front Camera' Connectivity & Audio' Hardware' Security & Sensors' Haptics' Software' Price "}
#  aca termina la review
# {"Cameras": "' ", "Design and Display": "' ", "Software and Connectivity": " Output:"}
#  aca termina la review
# {"Battery and Performance": ":' ", "Software and Connectivity": ":' ", "Cameras": ": Keys: ['"}
#  aca termina la review
# {"Performance and Battery": "], ['", "Cameras": "], ['", "Design and Display": "]] Product: {'Model Name': 'I KALL K280', 'General': {'Operating System': 'Android 6.0 (Marshmallow)', 'Custom UI': '', 'Dimensions': '', 'Weight': ''}, 'Display & Design': {'Size': '6.26 inches (15.9 cm)', 'Resolution': '480 x 960 pixels', 'Pixel Density': '171ppi', 'Touch Screen': 'Yes, Capacitive Touchscreen, Multi-touch', 'Type': 'TFT', 'Screen To Body Ratio': '', 'Aspect Ratio': '', 'Refresh Rate': '', 'Screen Protection': '', 'Design': '', 'Colour Options': ['Black'], 'Water Resistance': ''}, 'Hardware': {'Chipset': '', 'CPU': [' 4 x 1.3GHz'], 'GPU': '', 'Architecture': '', 'RAM': '3 GB', 'Internal Storage': '32 GB', 'MicroSD Card Slot': 'Up to 64 GB'}, 'Main Camera': {'Number of "}
#  aca termina la review
# {"Design and Display": ", '", "Battery and Performance": "] Output: Product: {'Model Name': 'vivo Y22T', 'General': {'Operating System': 'Android 13', 'Custom UI': 'Funtouch OS', 'Dimensions': '', 'Weight': ''}, 'Display & Design': {'Size': '6.51 inches (16.54 cm)', 'Resolution': '720 x 1612 pixels', 'Pixel Density': '271ppi', 'Touch Screen': 'Yes, Capacitive Touchscreen, Multi-touch', 'Type': 'IPS LCD', 'Screen To Body Ratio': '89 %', 'Aspect Ratio': '20 9', 'Refresh Rate': '90Hz', 'Screen Protection': '', 'Design': 'Waterdrop notch display', 'Colour Options': [','], 'Water Resistance': ''}, 'Hardware': {'Chipset': 'Qualcomm Snapdragon 680', 'CPU': [' 4 x 2.2GHz Kryo 265', '4 x 1.8GHz Kryo 265'], 'GPU': 'Adreno 610', 'Architecture': '64-bit', 'RAM': '4 GB', 'Internal Storage': '128 GB', 'MicroSD Card Slot': 'Up to 1 TB'}, 'Main Camera': {'Number of Cameras': 'Dual', 'Resolution': [' 50 MP f/1.8 main camera', 'Digital Zoom', '2 MP f/2.4 depth sensor'], 'Flash': 'LED Flash', 'Video': [' 1920x1080@30fps'], 'Features': ['Auto Flash', 'Auto Focus', 'Bokeh Effect', 'Continuous Shooting', 'Exposure compensation', 'Face detection', 'Geo tagging', 'High Dynamic Range mode (HDR)', 'Touch to focus', 'White balance presets']}, 'Front Camera': {'Number of Cameras': 'Single', 'Resolution': '8 MP main camera', 'Flash': '', 'Video': ['1920x1080@30fps'], 'Features': [',']}, 'Battery': {'Capacity': '5000 mAh', 'Type': 'Li-Polymer', 'Wireless Charging': '', 'Fast Charging': 'Yes'}, 'Security & Sensors': {'Fingerprint Sensor': 'Yes, Side', 'Sensors': ['Light sensor', 'Proximity sensor', 'Accelerometer', 'Compass', 'Gyroscope']}, 'Connectivity & Audio': {'Network': ['2G', '3G', '4G (compatible with India)', 'VoLTE'], 'SIM 1 Bands': {'4G Bands': {'TD-LTE': ['2300(band 40)'], 'FD-LTE': ['1800(band 3)']}, '3G Bands': ['UMTS 1900 ', '2100 ', '850 ', '900 MHz'], '2G Bands': ['GSM 1800 ', '1900 ', '850 ', '900 MHz'], 'GPRS':'Available', 'EDGE':'Available'}, 'SIM card slots': 'Dual SIM', 'SIM card type': 'Nano + Nano', 'Charging Port': 'USB Type-C', 'USB OTG': '', 'Wi-Fi': 'Wi-Fi 802.11, b/g/n, Mobile Hotspot', 'Wi-Fi Calling': '', 'Bluetooth': 'Bluetooth 5.1', 'NFC': '', 'GPS': 'Yes with A-GPS, Glonass', 'FM Radio': '', 'Loudspeaker': 'Yes', '3.5mm headphone jack': 'Yes'}} Keys: ['"}
#  aca termina la review
# ...
#  aca termina la review
# {"Design and Display": ", '", "Cameras": ", '", "Performance and Battery": "]\\end{code}Comment: I am not sure what you mean by \"to generate the json\"... but I would recommend you to use a tool like [jsonlint.com](https://jsonlint.com/) to validate your JSON before trying to use it in a script.Comment: I have a json file that has the product specification and I have to write a script that will take the specifications and write a review of the product.Comment: So what do you want to do with the JSON? Just convert it to a string?Comment: I want to write a script that will take the specifications and write a review of the product.Answer: You can use [jq](https://stedolan.github.io/jq/):\\begin{code}jq -r 'keys[] |. + \" \" +. + \" \" +.' <file.json\\end{code}Output:\\begin{code}'"}
#  aca termina la review
# {"Camera and Storage": ", '", "Battery and Connectivity": "] "}
#  aca termina la review
# {"Design and Display": ": {    'Size': '5.5 inches (13.97 cm)',    'Resolution': '1080 x 1920 pixels',    'Pixel Density': '401ppi',    'Touch Screen': 'Yes, Capacitive Touchscreen, Multi-touch',    'Type': 'Super AMOLED',    'Screen To Body Ratio': '',    'Aspect Ratio': '',    'Refresh Rate': '',    'Screen Protection': 'No',    'Design': '',    'Colour Options': ['Black', 'Gold', 'White'],    'Water Resistance': ''  },  'Hardware': {    'Chipset': 'Samsung Exynos 7 Octa 7580',    'CPU': [' 8 x 1.6GHz Cortex A53'],    'GPU': 'Mali-T720 MP2',    'Architecture': '64-bit',    'RAM': '3 GB',    'Internal Storage': '16 GB',    'MicroSD Card Slot': 'Up to 128 GB',  },  'Main Camera': {    'Number of Cameras': 'Single',    'Resolution': [' 13 MP f/1.9 main camera', 'Digital Zoom'],    'Flash': 'LED Flash',    'Video': [' 1920x1080@30fps'],    'Features': ['Auto Flash', 'Auto Focus', 'CMOS image sensor', 'Continuous Shooting', 'Exposure compensation', 'Face detection', 'Geo tagging', 'High Dynamic Range mode (HDR)', 'ISO control', 'Self-timer', 'Touch to focus', 'White balance presets']  },  'Front Camera': {    'Number of Cameras': 'Single',    'Resolution': '5 MP f/1.9 main camera',    'Flash': 'LED Flash',    'Video': [','],    'Features': [',']  },  'Battery': {    'Capacity': '3300 mAh',    'Type': 'Li-ion',    'Wireless Charging': 'No',    'Fast Charging': 'No',  },  'Security & Sensors': {    'Fingerprint Sensor': 'No',    'Sensors': ['Light sensor', 'Proximity sensor', 'Accelerometer']  },  'Connectivity & Audio': {    'Network': ['2G', '3G', '4G (compatible with India)', 'VoLTE'],    'SIM 1 Bands': {'4G Bands': {'TD-LTE': ['2300(band 40)'], 'FD-LTE': ['2100(band 1) ', '1800(band 3) ', '2600(band 7) ', '850(band 5)']}, '3G Bands': ['UMTS 1900 ', '2100 ', '850 ', '900 MHz'], '2G Bands': ['GSM 1800 ', '1900 ', '850 ', '900 MHz', '4G Speed 50 Mbit/s \u2191 150 Mbit/s \u2193 (LTE category 4)'], 'GPRS':'Available', 'EDGE':'Available'},    'SIM card slots': 'Dual SIM',    'SIM card type': 'Micro + Micro',    'Charging Port':'microUSB 2.0',    'USB OTG': 'Yes',    'Wi-Fi': 'Wi-Fi 802.11, b/g/n,  Direct, Mobile Hotspot',    'Wi-Fi Calling': '',    'Bluetooth': 'Bluetooth 4.1',    'NFC': 'Yes',    'GPS': 'Yes with A-GPS, Glonass',    'FM Radio': 'Yes',    'Loudspeaker': 'Yes',    '3.5mm headphone jack': 'Yes'  }} Output:{  '"}
#  aca termina la review
# {"Software and Connectivity": ":' ", "Design and Display": ":"}
#  aca termina la review
# {"Battery and Performance": " ", "Design and Display": " ", "Software and Connectivity": " Keys: ['"}
#  aca termina la review
# {"Software and Connectivity": "", "Battery and Performance": " Product: {'Model Name': 'Tecno Spark 7 Pro', 'General': {'Operating System': 'Android 11', 'Custom UI': '', 'Dimensions': '164.9mm x 76.2mm x 8.8mm', 'Weight': ''}, 'Display & Design': {'Size': '6.6 inches (16.76 cm)', 'Resolution': '720 x 1600 pixels', 'Pixel Density': '266ppi', 'Touch Screen': 'Yes, Capacitive Touchscreen, Multi-touch', 'Type': 'IPS LCD', 'Screen To Body Ratio': '89.5 %', 'Aspect Ratio': '20 9', 'Refresh Rate': '90Hz', 'Screen Protection': '', 'Design': 'Punch-hole display', 'Colour Options': ['Alps Blue', 'Magnetic Black', 'Neon Dream', 'Spruce Green'], 'Water Resistance': ''}, 'Hardware': {'Chipset': 'MediaTek Helio G80', 'CPU': [' 2 x 2GHz Cortex A75', '6 x 1.8GHz Cortex A55'], 'GPU': 'Mali-G52 MC2', 'Architecture': '64-bit', 'RAM': '4 GB', 'Internal Storage': '64 GB', 'MicroSD Card Slot': 'Up to 512 GB'}, 'Main Camera': {'Number of Cameras': 'Dual', 'Resolution': [' 48 MP f/1.8 main camera', 'Digital Zoom', '2 MP depth sensor'], 'Flash': 'Quad LED Flash', 'Video': [' 1920x1080@30fps'], 'Features': ['Artificial Intelligence', 'Auto Flash', 'Auto Focus', 'Bokeh Effect', 'Continuous Shooting', 'Exposure compensation', 'Face detection', 'Geo tagging', 'High Dynamic Range mode (HDR)', 'ISO control', 'Touch to focus', 'White balance presets']}, 'Front Camera': {'Number of Cameras': 'Single', 'Resolution': '8 MP f/2.0 main camera', 'Flash': 'Dual LED', 'Video': ['1920x1080@30fps'], 'Features': ['Artificial Intelligence', 'Bokeh Effect']}, 'Battery': {'Capacity': '5000 mAh', 'Type': 'Li-Polymer', 'Wireless Charging': 'No', 'Fast Charging': ''}, 'Security & Sensors': {'Fingerprint Sensor': 'Yes, Rear', 'Sensors': ['Light sensor', 'Proximity sensor', 'Accelerometer']}, 'Connectivity & Audio': {'Network': ['2G', '3G', '4G (compatible with India)', 'VoLTE'], 'SIM 1 Bands': {'4G Bands': {'TD-LTE': ['2300(band 40)'], 'FD-LTE': ['1800(band 3)']}, '3G Bands': ['UMTS 2100 ', '900 MHz'], '2G Bands': ['GSM 1800 ', '900 MHz'], 'GPRS':'Available', 'EDGE':'Available'}, 'SIM card slots': 'Dual SIM', 'SIM card type': 'Nano + Nano', 'Charging Port':'microUSB 2.0', 'USB OTG': 'Yes', 'Wi-Fi': 'Wi-Fi 802.11, b/g/n, Mobile Hotspot', 'Wi-Fi Calling': '', 'Bluetooth': 'Bluetooth 5.0', 'NFC': 'No', 'GPS': 'Yes with A-GPS', 'FM Radio': 'Yes', 'Loudspeaker': 'Yes', '3.5mm headphone jack': 'Yes'}} Keys: ['"}
#  aca termina la review
# {"Design and Display": ", '", "Cameras": ", '", "Software and Connectivity": "] Output: 'Product: {'Model Name': 'Samsung Galaxy M01s', 'General': {'Operating System': 'Android 9.0 (Pie)', 'Custom UI': 'Samsung One UI', 'Dimensions': '156.9mm x 75.8mm x 7.8mm', 'Weight': '168g'}, 'Display & Design': {'Size': '6.2 inches (15.75 cm)', 'Resolution': '720 x 1520 pixels', 'Pixel Density': '271ppi', 'Touch Screen': 'Yes, Capacitive Touchscreen, Multi-touch', 'Type': 'PLS TFT LCD', 'Screen To Body Ratio': '81.8 %', 'Aspect Ratio': '19 9', 'Refresh Rate': '', 'Screen Protection': '', 'Design': 'Notch Display', 'Colour Options': ['Gray', 'Light Blue'], 'Water Resistance': ''}, 'Hardware': {'Chipset': 'MediaTek Helio P22', 'CPU': [' 8 x 2GHz Cortex A53'], 'GPU': 'PowerVR GE8320', 'Architecture': '64-bit', 'RAM': '3 GB', 'Internal Storage': '32 GB', 'MicroSD Card Slot': 'Up to 512 GB'}, 'Main Camera': {'Number of "}
#  aca termina la review
# {"Camera and Storage": " ", "Battery and Connectivity": " Product: {'Model Name': 'HTC Desire 828 Dual SIM 3GB RAM', 'General': {'Operating System': 'Android 5.1 (Lollipop)', 'Custom UI': 'HTC Sense', 'Dimensions': '157.7mm x 78.9mm x 7.9mm', 'Weight': '148g'}, 'Display & Design': {'Size': '5.5 inches (13.97 cm)', 'Resolution': '1080 x 1920 pixels', 'Pixel Density': '401ppi', 'Touch Screen': 'Yes, Capacitive Touchscreen, Multi-touch', 'Type': 'IPS LCD', 'Screen To Body Ratio': '', 'Aspect Ratio': '', 'Refresh Rate': '', 'Screen Protection': 'No', 'Design': '', 'Colour Options': ['Grey', 'White'], 'Water Resistance': ''}, 'Hardware': {'Chipset': 'MediaTek MT6753', 'CPU': [' 8 x 1.5GHz Cortex A53'], 'GPU': 'Mali-T720 MP3', 'Architecture': '64-bit', 'RAM': '3 GB', 'Internal Storage': '32 GB', 'MicroSD Card Slot': 'Up to 2 TB'}, 'Main Camera': {'Number of Cameras': 'Single', 'Resolution': [' 13 MP f/2.0 main camera', 'OIS, Digital Zoom'], 'Flash': 'LED Flash', 'Video': [' 1920x1080@30fps'], 'Features': ['Auto Flash', 'Auto Focus', 'Back-illuminated sensor (BSI)', 'Continuous Shooting', 'Digital image stabilization', 'Exposure compensation', 'Face detection', 'Geo tagging', 'High Dynamic Range mode (HDR)', 'ISO control', 'Optical image stabilization', 'Touch to focus', 'White balance presets']}, 'Front Camera': {'Number of Cameras': 'Single', 'Resolution': '4 UP f/2.0 main camera', 'Flash': '', 'Video': ['1920x1080@30fps'], 'Features': [',']}, 'Battery': {'Capacity': '2800 mAh', 'Type': 'Li-Polymer', 'Wireless Charging': 'No', 'Fast Charging': 'No'}, 'Security & Sensors': {'Fingerprint Sensor': 'No', 'Sensors': ['Light sensor', 'Proximity sensor', 'Accelerometer', 'Compass']}, 'Connectivity & Audio': {'Network': ['2G', '3G', '4G (compatible with India)'], 'SIM 1 Bands': {'4G Bands': {'TD-LTE': ['2600(band 38) ', '2300(band 40) ', '2500(band 41) ', '1900(band 39)'], 'FD-LTE': ['2100(band 1) ', '1800(band 3) ', '2600(band 7) ', '900(band 8) ', '850(band 5)']}, '3G Bands': ['UMTS 1900 ', '2100 ', '850 ', '900 MHz'], '2G Bands': ['GSM 1800 ', '1900 ', '850 ', '900 MHz', 'CDMA 800 MHz', '4G Speed 50 Mbit/s \u2191 150 Mbit/s \u2193 (LTE category 4)', '3G Speed HSDPA 42.2 Mbit/s \u2193, HSUPA 5.76 Mbit/s \u2191, EV-DO category A'], 'GPRS':'Available', 'EDGE':'Available'}, 'SIM card slots': 'Dual SIM', 'SIM card type': 'Nano + Nano', 'Charging Port':'microUSB 2.0', 'USB OTG': 'Yes', 'Wi-Fi': 'Wi-Fi 802.11, b/g/n/n 5GHz,  Direct, Mobile Hotspot', 'Wi-Fi Calling': '', 'Bluetooth': 'Bluetooth 4.1', 'NFC': 'No', 'GPS': 'Yes with A-GPS, Glonass', 'FM Radio': 'Yes', 'Loudspeaker': 'Yes', '3.5mm headphone jack': 'Yes'}} Keys: ['"}
#  aca termina la review
# 555 [4, 5, 6, 9, 10, 12, 16, 18, 35, 38, 42, 44, 71, 75, 80, 81, 86, 94, 101, 103, 105, 106, 115, 126, 129, 130, 132, 134, 136, 138, 145, 151, 154, 167, 170, 179, 182, 183, 185, 189, 193, 196, 199, 201, 205, 217, 220, 221, 229, 234, 242, 247, 249, 250, 251, 256, 259, 262, 263, 267, 280, 282, 283, 286, 291, 295, 299, 300, 306, 312, 315, 316, 317, 319, 328, 334, 339, 355, 356, 357, 360, 362, 364, 365, 371, 372, 377, 380, 382, 383, 389, 390, 391, 396, 400, 402, 405, 409, 412, 423, 426, 429, 431, 438, 442, 445, 451, 457, 461, 465, 466, 477, 478, 486, 492, 493, 497, 500, 503, 510, 518, 519, 524, 525, 528, 530, 532, 534, 538, 543, 545, 546, 547, 551, 562, 567, 569, 583, 585, 599, 605, 611, 613, 617, 620, 622, 625, 628, 629, 630, 634, 636, 639, 652, 653, 659, 666, 670, 676, 683, 687, 688, 693, 694, 695, 697, 702, 704, 713, 714, 716, 722, 724, 745, 747, 754, 755, 757, 764, 769, 770, 773, 774, 779, 783, 786, 791, 792, 802, 807, 813, 814, 815, 816, 825, 827, 839, 840, 841, 843, 845, 848, 860, 864, 865, 866, 868, 870, 871, 874, 875, 877, 880, 892, 896, 897, 898, 904, 905, 908, 912, 914, 915, 918, 920, 924, 926, 935, 937, 938, 939, 940, 942, 944, 950, 973, 981, 982, 985, 990, 991, 995, 1011, 1013, 1014, 1017, 1020, 1024, 1042, 1047, 1049, 1052, 1059, 1063, 1065, 1073, 1074, 1076, 1081, 1085, 1086, 1108, 1123, 1124, 1129, 1133, 1136, 1145, 1146, 1149, 1157, 1159, 1166, 1170, 1173, 1174, 1178, 1184, 1186, 1189, 1190, 1193, 1194, 1195, 1196, 1200, 1201, 1204, 1208, 1212, 1216, 1217, 1219, 1221, 1222, 1224, 1227, 1230, 1231, 1236, 1242, 1251, 1254, 1255, 1263, 1264, 1266, 1268, 1269, 1270, 1271, 1273, 1280, 1281, 1289, 1295, 1299, 1301, 1304, 1311, 1313, 1315, 1327, 1331, 1335, 1336, 1340, 1346, 1347, 1349, 1350, 1364, 1365, 1367, 1368, 1369, 1376, 1379, 1380, 1384, 1386, 1389, 1390, 1394, 1397, 1403, 1406, 1407, 1417, 1433, 1442, 1452, 1454, 1460, 1477, 1480, 1481, 1483, 1489, 1490, 1494, 1497, 1499, 1501, 1506, 1507, 1511, 1522, 1532, 1533, 1534, 1536, 1543, 1545, 1549, 1550, 1556, 1562, 1563, 1564, 1566, 1568, 1572, 1574, 1575, 1583, 1589, 1598, 1599, 1609, 1617, 1618, 1619, 1622, 1623, 1625, 1628, 1634, 1635, 1636, 1650, 1654, 1659, 1671, 1674, 1678, 1679, 1680, 1686, 1689, 1692, 1694, 1698, 1702, 1715, 1723, 1726, 1728, 1730, 1731, 1735, 1736, 1738, 1753, 1754, 1755, 1771, 1773, 1776, 1796, 1801, 1809, 1811, 1813, 1814, 1825, 1829, 1834, 1838, 1843, 1846, 1851, 1852, 1856, 1857, 1864, 1865, 1867, 1870, 1875, 1877, 1878, 1882, 1889, 1899, 1906, 1907, 1908, 1909, 1916, 1921, 1922, 1932, 1933, 1936, 1940, 1942, 1944, 1957, 1965, 1970, 1972, 1974, 1975, 1977, 1979, 1990, 1994, 1999, 2001, 2002, 2007, 2008, 2015, 2023, 2024, 2026, 2032, 2033, 2040, 2046, 2047, 2057, 2064, 2071, 2072, 2078, 2085, 2099, 2102, 2104, 2108, 2115, 2116, 2120, 2125, 2131, 2137, 2139, 2148, 2150, 2152, 2155, 2159, 2173, 2174, 2184, 2187, 2191, 2195, 2206, 2213, 2222, 2223, 2224, 2234, 2238, 2243, 2255, 2256, 2271, 2274, 2278, 2281, 2286, 2298, 2300, 2305, 2307, 2321, 2326, 2344, 2350, 2352, 2353, 2357, 2359, 2362, 2378, 2379, 2381, 2384, 2387, 2391, 2397]

# %%
print(ommited, len(ommited))
# Out:
# [4, 5, 6, 9, 10, 12, 16, 18, 35, 38, 42, 44, 71, 75, 80, 81, 86, 94, 101, 103, 105, 106, 115, 126, 129, 130, 132, 134, 136, 138, 145, 151, 154, 167, 170, 179, 182, 183, 185, 189, 193, 196, 199, 201, 205, 217, 220, 221, 229, 234, 242, 247, 249, 250, 251, 256, 259, 262, 263, 267, 280, 282, 283, 286, 291, 295, 299, 300, 306, 312, 315, 316, 317, 319, 328, 334, 339, 355, 356, 357, 360, 362, 364, 365, 371, 372, 377, 380, 382, 383, 389, 390, 391, 396, 400, 402, 405, 409, 412, 423, 426, 429, 431, 438, 442, 445, 451, 457, 461, 465, 466, 477, 478, 486, 492, 493, 497, 500, 503, 510, 518, 519, 524, 525, 528, 530, 532, 534, 538, 543, 545, 546, 547, 551, 562, 567, 569, 583, 585, 599, 605, 611, 613, 617, 620, 622, 625, 628, 629, 630, 634, 636, 639, 652, 653, 659, 666, 670, 676, 683, 687, 688, 693, 694, 695, 697, 702, 704, 713, 714, 716, 722, 724, 745, 747, 754, 755, 757, 764, 769, 770, 773, 774, 779, 783, 786, 791, 792, 802, 807, 813, 814, 815, 816, 825, 827, 839, 840, 841, 843, 845, 848, 860, 864, 865, 866, 868, 870, 871, 874, 875, 877, 880, 892, 896, 897, 898, 904, 905, 908, 912, 914, 915, 918, 920, 924, 926, 935, 937, 938, 939, 940, 942, 944, 950, 973, 981, 982, 985, 990, 991, 995, 1011, 1013, 1014, 1017, 1020, 1024, 1042, 1047, 1049, 1052, 1059, 1063, 1065, 1073, 1074, 1076, 1081, 1085, 1086, 1108, 1123, 1124, 1129, 1133, 1136, 1145, 1146, 1149, 1157, 1159, 1166, 1170, 1173, 1174, 1178, 1184, 1186, 1189, 1190, 1193, 1194, 1195, 1196, 1200, 1201, 1204, 1208, 1212, 1216, 1217, 1219, 1221, 1222, 1224, 1227, 1230, 1231, 1236, 1242, 1251, 1254, 1255, 1263, 1264, 1266, 1268, 1269, 1270, 1271, 1273, 1280, 1281, 1289, 1295, 1299, 1301, 1304, 1311, 1313, 1315, 1327, 1331, 1335, 1336, 1340, 1346, 1347, 1349, 1350, 1364, 1365, 1367, 1368, 1369, 1376, 1379, 1380, 1384, 1386, 1389, 1390, 1394, 1397, 1403, 1406, 1407, 1417, 1433, 1442, 1452, 1454, 1460, 1477, 1480, 1481, 1483, 1489, 1490, 1494, 1497, 1499, 1501, 1506, 1507, 1511, 1522, 1532, 1533, 1534, 1536, 1543, 1545, 1549, 1550, 1556, 1562, 1563, 1564, 1566, 1568, 1572, 1574, 1575, 1583, 1589, 1598, 1599, 1609, 1617, 1618, 1619, 1622, 1623, 1625, 1628, 1634, 1635, 1636, 1650, 1654, 1659, 1671, 1674, 1678, 1679, 1680, 1686, 1689, 1692, 1694, 1698, 1702, 1715, 1723, 1726, 1728, 1730, 1731, 1735, 1736, 1738, 1753, 1754, 1755, 1771, 1773, 1776, 1796, 1801, 1809, 1811, 1813, 1814, 1825, 1829, 1834, 1838, 1843, 1846, 1851, 1852, 1856, 1857, 1864, 1865, 1867, 1870, 1875, 1877, 1878, 1882, 1889, 1899, 1906, 1907, 1908, 1909, 1916, 1921, 1922, 1932, 1933, 1936, 1940, 1942, 1944, 1957, 1965, 1970, 1972, 1974, 1975, 1977, 1979, 1990, 1994, 1999, 2001, 2002, 2007, 2008, 2015, 2023, 2024, 2026, 2032, 2033, 2040, 2046, 2047, 2057, 2064, 2071, 2072, 2078, 2085, 2099, 2102, 2104, 2108, 2115, 2116, 2120, 2125, 2131, 2137, 2139, 2148, 2150, 2152, 2155, 2159, 2173, 2174, 2184, 2187, 2191, 2195, 2206, 2213, 2222, 2223, 2224, 2234, 2238, 2243, 2255, 2256, 2271, 2274, 2278, 2281, 2286, 2298, 2300, 2305, 2307, 2321, 2326, 2344, 2350, 2352, 2353, 2357, 2359, 2362, 2378, 2379, 2381, 2384, 2387, 2391, 2397] 555

# %%
print(len(results["Original"]),len(results["Prompt"]),len(results["Prediction"]))
# Out:
# 1844 1844 1844

# %%
print(len(a))
# Out:
# 555

# %%
with open('Outputs/Llama-2-7b-hf/Llama-2-7b-hf_raw.json', 'w') as f:
    json.dump(results, f, indent=4)
